# %%
# %load_ext autoreload
# %autoreload 2
import torch
from torchvision.io import read_image
from glob import glob
import matplotlib.pyplot as plt

from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
import torchvision.transforms.functional as F
from torch.utils.data import DataLoader
import torchvision.transforms as T
import PIL
from PIL import Image

import numpy as np
import seaborn as sns
# torch_model = torch.hub.load('facebookresearch/dino:main', 'dino_vitb8')

img_size = 640
patch_size = 16

# %%
class DINODataset(Dataset):
    def __init__(self, img_dir, transform=None):
        self.img_dir = img_dir
        self.img_names = glob(img_dir + '/*')
        self.transform = transform
        
    def __len__(self):
        return len(self.img_names)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        with open(self.img_names[idx], 'rb') as f:
            img = Image.open(f)
            img = img.convert('RGB')
        
        if self.transform:
            img = self.transform(img)
        
        return img

# %%
transform = T.Compose([
        T.Resize((img_size, img_size)),
        T.ToTensor(),
        T.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

dataset = DINODataset('data/', transform=transform)
dataloader = DataLoader(dataset)


t = T.Compose([
        T.Resize((img_size, img_size)),
        T.ToTensor()
])

dataset_no_norm = DINODataset('data/', transform=t)
loader_no_norm = DataLoader(dataset_no_norm)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Load model with our own code

# %%
import vision_transformer as vits
class PatchedTransformer(vits.VisionTransformer):
    
    def forward(self, x):
        x = self.prepare_tokens(x) # (15 x 15 + 1, 768) 
        
        for blk in self.blocks:
            x = blk(x)
        x = self.norm(x)
        return x

# %%
vits.VERBOSE = False

# model = vits.__dict__['vit_base'](patch_size=16, num_classes=0)

model = vits.__dict__['vit_base'](patch_size=16, num_classes=0)

url = "dino_vitbase16_pretrain/dino_vitbase16_pretrain.pth"
state_dict = torch.hub.load_state_dict_from_url(url="https://dl.fbaipublicfiles.com/dino/" + url)

model.eval()
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Inference
#
# init:
# - embedding dimension (768)
#
#
# 1. Put input image of size `(B, nc, w, h)` to `model.forward`
# 2. Run PatchEmbed: run convolutional layer of kernel size `(patch_size, patch_size)` on input image, and get `embed_dim` out channels
# 3. We will get `img_size // patch_size * img_size // patch_size` output dimension along with `embed_dim`, because we will run equal length patch for each position in the image, with stride `patch_size`
# 4. Run through

# %% [markdown]
# ## Dino style masking

# %%
def shape_attention_to_grid(attn_raw, w_featmap, h_featmap):
    attn = attn_raw.detach().numpy().copy()
    nh = attn.shape[1]

    attn = attn[0, :, 0, 1:].reshape(nh, -1)
    attn = attn.reshape(nh, w_featmap, h_featmap)
    return attn

# %%
vits.VERBOSE = False

# %% [markdown]
# Run predictions on original image

# %% [markdown]
# Run predictions on masked images

# %% [markdown]
# ### Masking and clustering
#
# Cut objects patch by patch to see what kind of heatmaps we get. Can we improve Dino on multi-object? We can do it also on image level, but then our image wont be rectangular. Or will it?
#
# 1.
# 2. embed input image (240, 240) to patches 16x16, produce map 15x15
# 3. Calculate difference of unmasked image to masked
# 4. Repeat N times
# 5. Get mean of all differences, visualize
#
# Goal is, that when important patch is masked, then the representation close to that patch is greatly changed. Problem is, that with mean we are hiding the differences.

# %%
vits.VERBOSE= True
# Out:
# [autoreload of vision_transformer failed: Traceback (most recent call last):
#   File "C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "O:\Python\dino\vision_transformer.py", line 258
#     x[]
#       ^
# SyntaxError: invalid syntax
# ]

# %%
from copy import deepcopy
from torch.linalg import norm

outputs = []
model.to(device)
model.eval()

w_featmap = img_size // patch_size
h_featmap = img_size // patch_size

for img in dataloader:
    orig_out, _, _ , _, _ = model(img, i_crop=0, crop=False)
    orig_out = orig_out.squeeze(0)[0, :]
    # Cut patches out of image
    for n in range(1600):
        cropped_img = deepcopy(img, crop=False)

        cropped_img = cropped_img.to(device)

        out = model(img, i_crop=n)

        outputs.append(out)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b1f3cee3e077> in <module>
#      10
#      11 for img in dataloader:
# ---> 12     orig_out, _, _ , _, _ = model(img, crop=False)
#      13     orig_out = orig_out.squeeze(0)[0, :]
#      14     # Cut patches out of image
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# TypeError: forward() missing 1 required positional argument: 'i_crop'

# %%
out[0].shape
# Out:
# torch.Size([1, 1601, 768])

# %% [markdown]
# Stack the masked predictions to single tensor

# %%
torch_outs = torch.stack(outputs)

# %%
sns.heatmap(torch_outs)

# %%
torch_outs.shape
# Out:
# torch.Size([4, 768])

# %%
import torchvision.transforms as T
import torchvision.transforms.functional as F

c = T.RandomCrop(64)
p = c.get_params(t, (64, 64))
mask = F.crop(t, *p)
mask[:] = 0
plt.imshow(t[0, 0, :])

# %% [markdown]
# Get euclidean distance between original image and patched tensors

# %% [markdown]
# Visualize each of the euclidean differences and maskings

# %% [markdown]
# How does the object patching affect CLS token.

# %%
import seaborn as sns
# Drop CLS
# reshaped_diff = norm_diff[:, 1:].reshape(-1, 30, 30)
shaped_outs = torch_outs[:, 1:].reshape(-1, img_size // 16 , img_size // 16).detach()
# shaped_outs = orig_attn[:, 1:].mean(-1).reshape(1, img_size // 16 , img_size // 16).detach()
plt.figure(figsize = (12,12))
plt.title('Original image, mean taken over embeddings')
sns.heatmap(shaped_outs[3, :])

# %% [markdown]
# ## View CLS attention embeddings patch by patch

# %%
import torchvision.transforms.functional as TF
import matplotlib.patches as patches


img_no_norm = next(iter(loader_no_norm))
img = next(iter(dataloader))

out = model.get_last_selfattention(img)

# %% [markdown]
# Image without any patches

# %%
w_featmap = img.shape[-2] // 16
h_featmap = img.shape[-1] // 16
attn_grid = shape_attention_to_grid(out, w_featmap, h_featmap)

# %%
plt.imshow(attn_grid.mean(0))

# %% [markdown]
# ## Test different patchings

# %%
import matplotlib.patches as patches

def visualize_patched_image(torch_img, w_mask, h_mask, x_start, y_start):
    np_img = np.array(TF.to_pil_image(torch_img.squeeze(0)))

    fig, ax = plt.subplots()

    rect = patches.Rectangle((x_start,y_start), w_mask, h_mask)
    ax.imshow(np_img)
    ax.add_patch(rect)
    
def visualize_crop(img, top, left, height, width):
    crop = F.crop(img, top=top, left=left, heigh=height, width=width)
    plt.imshow(crop)

# %% [markdown]
# Remove patch from imaeg

# %%
x_range = range(x_start, x_start + w_mask)
y_range = range(y_start, y_start + h_mask)
xy_mesh = np.meshgrid(x_range, y_range)[0]
np_img_n = np.delete(np_img, xy_mesh, axis=0)
# np_img_n = np.delete(np_img_n, xy_mesh, axis=1)

# %% [markdown]
# ## CLS embeddings for patches

# %%
def predict_on_image(model, img):
    out = model(img, crop=False)[0]
    return out.squeeze(0)[0, :]

# %% [markdown]
# Original

# %%
img = next(iter(loader_no_norm))
orig_out = predict_on_image(model, img)

# %%
orig_out.shape
# Out:
# torch.Size([1600, 768])

# %% [markdown]
# Patch right car

# %%
# Right car
top = 290
left = 360
height = 150
width = 170

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

large_right_out = predict_on_image(model, crop.unsqueeze(0))

# %% [markdown]
# Right large global

# %%
# Right car
top = 150
left = 360
height = 300
width = 220

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

right_out = predict_on_image(model, crop.unsqueeze(0))

# %% [markdown]
# Patch left car

# %%
# Right car
top = 290
left = 100
height = 150
width = 220

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

left_out = predict_on_image(model, crop.unsqueeze(0))

# %% [markdown]
# Half left car

# %%
# Right car
top = 290
left = 50
height = 150
width = 180

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

half_left_out = predict_on_image(model, crop.unsqueeze(0))
# Out:
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3455: UserWarning: Default upsampling behavior when mode=bicubic is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3500: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# Background clouds

# %%
top = 0
left = 0
height = 150
width = 500

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

bg_out = predict_on_image(model, crop.unsqueeze(0))

# %% [markdown]
# Left-right car overlap

# %%
# Right car
top = 290
left = 100
height = 300
width = 400

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

l_r_car_out = predict_on_image(model, crop.unsqueeze(0))
# Out:
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3455: UserWarning: Default upsampling behavior when mode=bicubic is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3500: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %%
# Right car
top = 0
left = 0
height = 300
width = 300

img = next(iter(loader_no_norm)).squeeze(0)
crop = F.crop(img, top=top, left=left, height=height, width=width)
plt.imshow(crop.permute(1,2,0))

bg_l_out = predict_on_image(model, crop.unsqueeze(0))

# %% [markdown]
# ## Visualize embeddings

# %%
out_dict = {"orig_out": orig_out, 
            "right_out": right_out, 
            "large_right_out": large_right_out, 
            "left_out": left_out, 
            "l_r_car_out": l_r_car_out, 
            "half_left_out":half_left_out}

outs = torch.stack(list(out_dict.values())).detach().numpy()

# %%
mat = outs @ outs.T
plt.imshow(mat)

# %%
from sklearn.decomposition import PCA

pca = PCA()
embeds = pca.fit_transform(outs)

fig, ax = plt.subplots(figsize=(14,14))

ax.scatter(embeds[:, 0], embeds[:, 1])

for i, txt in enumerate(['orig', 'right', 'large-right', 'left', 'left-right-car', 'half_left']):
    ax.annotate(txt, (embeds[i, 0], embeds[i, 1]))

# %%
import umap
reducer = umap.UMAP()

umap_embeds = reducer.fit_transform(outs)

fig, ax = plt.subplots()

ax.scatter(umap_embeds[:, 0], umap_embeds[:, 1])

for i, txt in enumerate(['orig', 'right', 'left']):
    ax.annotate(txt, (umap_embeds[i, 0], umap_embeds[i, 1]))
# Out:
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\umap\umap_.py:2345: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   "n_neighbors is larger than the dataset size; truncating to "
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:1592: RuntimeWarning: k >= N for N * N square matrix. Attempting to use scipy.linalg.eigh instead.
#   RuntimeWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-248-e1abe86657ea> in <module>
#       2 reducer = umap.UMAP()
#       3
# ----> 4 umap_embeds = reducer.fit_transform(outs)
#       5
#       6 fig, ax = plt.subplots()
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\umap\umap_.py in fit_transform(self, X, y)
#    2770             Local radii of data points in the embedding (log-transformed).
#    2771         """
# -> 2772         self.fit(X, y)
#    2773         if self.transform_mode == "embedding":
#    2774             if self.output_dens:
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\umap\umap_.py in fit(self, X, y)
#    2686                 self.n_epochs,
#    2687                 init,
# -> 2688                 random_state,  # JH why raw data?
#    2689             )
#    2690             # Assign any points that are fully disconnected from our manifold(s) to have embedding
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\umap\umap_.py in _fit_embed_data(self, X, n_epochs, init, random_state)
#    2737             self.random_state is None,
#    2738             self.verbose,
# -> 2739             tqdm_kwds=self.tqdm_kwds,
#    2740         )
#    2741
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\umap\umap_.py in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1082             random_state,
#    1083             metric=metric,
# -> 1084             metric_kwds=metric_kwds,
#    1085         )
#    1086         expansion = 10.0 / np.abs(initialisation).max()
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\umap\spectral.py in spectral_layout(data, graph, dim, random_state, metric, metric_kwds)
#     337                 tol=1e-4,
#     338                 v0=np.ones(L.shape[0]),
# --> 339                 maxiter=graph.shape[0] * 5,
#     340             )
#     341         else:
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1593
#    1594         if issparse(A):
# -> 1595             raise TypeError("Cannot use scipy.linalg.eigh for sparse A with "
#    1596                             "k >= N. Use scipy.linalg.eigh(A.toarray()) or"
#    1597                             " reduce k.")
#
# TypeError: Cannot use scipy.linalg.eigh for sparse A with k >= N. Use scipy.linalg.eigh(A.toarray()) or reduce k.

# %% [markdown]
# ## Plot attention maps

# %% [markdown]
# Get last attention layer

# %%
vits.VERBOSE = False
attn_img_raw = model.get_last_selfattention(img)

# %% [markdown]
# Plot attention map averaged over different attention heads

# %%
attn_grid = shape_attention_to_grid(attn_img_raw)

# %% [markdown]
# We see stripes, which mean that some patch attends strongly to all patches? This is a little bit unclear, and can't be compared to CLS output, because I don't think these features are trained explicitly.

# %% [markdown]
# ## Attention

# %% [markdown]
# We have <br>
#
# **query** - query to find out which token is most relevant to our current one<br>
# **key** - Key to match for the query. <br>
# **value** - idk<br>

# %% [markdown]
# Take 8x8 patches, 1 patch goes to one input. You unroll it to 64 -> run through embedding layer -> input to transformer.
#
# Transformers are permutation invariant, because they are basically MLP's with weight that is not fixed. We need to add positional encoding to make use of order. These positional encodings are learnable vectors, each vector has its own assigned

# %% [markdown]
# The output dimension is 768, which translates to 12 attention heads of 8x8 patches. The attention heads are due to Multi-headed attention, which combines multiple attention key, query, value pairs and thus learns different representations on each attention head.

# %% [markdown]
# With multi-headed attention we also have on extra weight matrix. All of the output attention heads are concatenated, and we need to multiply it somehow to reduce dimensionality - we multiply is with the extra weight matrix.

# %%
w_featmap = img_size // patch_size
h_featmap = img_size // patch_size

# %% [markdown]
# I believe for attention we have 12 connections (heads), each for one patch. The output embeddings are of length 900 + 1 CLS. What is the other 900 dim?

# %%
attentions = model.get_last_selfattention(img)
# Out:
# Cropped: 8%
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3455: UserWarning: Default upsampling behavior when mode=bicubic is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# C:\Users\teemu\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py:3500: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9c91ace024c8> in <module>
# ----> 1 attentions = model.get_last_selfattention(img)
#
# O:\Python\dino\vision_transformer.py in get_last_selfattention(self, x)
#     281         for i, blk in enumerate(self.blocks):
#     282             if i < len(self.blocks) - 1:
# --> 283                 x = blk(x)
#     284             else:
#     285                 # return attention of the last block
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# O:\Python\dino\vision_transformer.py in forward(self, x, return_attention)
#     129
#     130     def forward(self, x, return_attention=False):
# --> 131         y, attn = self.attn(self.norm1(x))
#     132         if return_attention:
#     133             return attn
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\modules\normalization.py in forward(self, input)
#     169     def forward(self, input: Tensor) -> Tensor:
#     170         return F.layer_norm(
# --> 171             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     172
#     173     def extra_repr(self) -> str:
#
# ~\anaconda3\envs\pytorchEnv\lib\site-packages\torch\nn\functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2200             layer_norm, (input,), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2201         )
# -> 2202     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2203
#    2204
#
# TypeError: layer_norm(): argument 'input' (position 1) must be Tensor, not tuple

# %%
attn_grid = shape_attention_to_grid(attentions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a03cafefb7ca> in <module>
# ----> 1 attn_grid = shape_attention_to_grid(attentions)
#
# NameError: name 'attentions' is not defined

# %% [markdown]
# Get how much tokens attend to CLS token, and exclude CLS token itself

# %%
attentions[0, :, 0, 1:].reshape(nh, -1).shape
# Out:
# torch.Size([12, 900])

# %%
attentions_shaped.reshape(nh, w_featmap, h_featmap).shape
# Out:
# torch.Size([12, 30, 30])

# %%
nh = attentions.shape[1] # number of head

# we keep only the output patch attention
attentions_shaped = attentions[0, :, 0, 1:].reshape(nh, -1)

# %%
# Shape from 12,900 to 12,30,30
attentions_shaped = attentions_shaped.reshape(nh, w_featmap, h_featmap)

# Interpolate from 30x30 to 240x240 or something
attentions_shaped = torch.nn.functional.interpolate(attentions_shaped.unsqueeze(0), 
                                              scale_factor=patch_size, 
                                              mode="nearest")[0].cpu().detach().numpy()

# %%
for atn in attentions_shaped:
    plt.figure()
    plt.imshow(atn)

# %%
from torchviz import make_dot

make_dot(out, params=dict(vitb8.named_parameters()))
